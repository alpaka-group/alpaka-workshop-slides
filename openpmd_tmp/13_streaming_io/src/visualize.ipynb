# %%
# %matplotlib inline
import visualize as vis
filename = "../build/heat.sst"
config = """
# parameters listed at
# https://adios2.readthedocs.io/en/v2.10.1/engines/engines.html#sst-sustainable-staging-transport

[adios2.engine.parameters]
OpenTimeoutSecs = 120
"""
vis.main(filename)
